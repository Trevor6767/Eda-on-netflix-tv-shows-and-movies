# %%
import numpy as np 
import pandas as pd
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
import warnings

# %%
warnings.filterwarnings('ignore')  # ignore notifications

# %%
df = pd.read_csv('C:/Users/Vineet/Desktop/New folder (2)/netflix_titles.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print(f'Number of missing values in DataFrame:\n{df.isna().sum()}')
# Out:
# Number of missing values in DataFrame:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %%
df['title'].value_counts()
# Out:
# Dick Johnson Is Dead                     1
# Ip Man 2                                 1
# Hannibal Buress: Comedy Camisado         1
# Turbo FAST                               1
# Masha's Tales                            1
#                                         ..
# Love for Sale 2                          1
# ROAD TO ROMA                             1
# Good Time                                1
# Captain Underpants Epic Choice-o-Rama    1
# Zubaan                                   1
# Name: title, Length: 8807, dtype: int64

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
#creating dataframe
# empty data frame
df_empty=pd.DataFrame()
df_empty.head()  #;)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# From dict
student_dict={'Name':['A','B','C'],'Age':[24,18,17],'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict).reset_index(drop=True) # without this adds an additional index column in df
df_student.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %%
#treating null values
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['director'].isnull().sum()
# Out:
# 2634

# %%
#modify or add new coloum
df['type']=df['type'].map({"Movie":'0',"Tv Shows":"1"})
df.head()
# Out:
#   show_id type                  title         director  \
# 0      s1    0   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  NaN          Blood & Water              NaN
# 2      s3  NaN              Ganglands  Julien Leclercq
# 3      s4  NaN  Jailbirds New Orleans              NaN
# 4      s5  NaN           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          6131 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#deleting a column
df=df.drop(['type'],axis=1)
#df=df.drop(['PassengerId'],axis=1,inplace=True)
df.head()
# Out:
#   show_id                  title         director  \
# 0      s1   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2          Blood & Water              NaN
# 2      s3              Ganglands  Julien Leclercq
# 3      s4  Jailbirds New Orleans              NaN
# 4      s5           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# Lets try to rename some columns. 
df=df.rename(columns={'show_id':'id','country':'origin','date_added':'time_info'})
df.head()
# Out:
#    id                  title         director  \
# 0  s1   Dick Johnson Is Dead  Kirsten Johnson
# 1  s2          Blood & Water              NaN
# 2  s3              Ganglands  Julien Leclercq
# 3  s4  Jailbirds New Orleans              NaN
# 4  s5           Kota Factory              NaN
#
#                                                 cast         origin  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#             time_info  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# All rows with pclass==3
df_third_class=df[df['release_year']==2020].reset_index(drop=True)
# w/0 drop=True it actually adds a index column rather.
df_third_class.head()
# Out:
#     id                                              title  \
# 0   s1                               Dick Johnson Is Dead
# 1  s17  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 2  s18                                    Falsa identidad
# 3  s33                                      Sex Education
# 4  s35                            Tayo and Little Wizards
#
#                                         director  \
# 0                                Kirsten Johnson
# 1  Pedro de Echave García, Pablo Azorín Williams
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#                                                 cast          origin  \
# 0                                                NaN   United States
# 1                                                NaN             NaN
# 2  Luis Ernesto Franco, Camila Sodi, Sergio Goyri...          Mexico
# ...

# %%
# Selecting some columns.
df1=df[['director','title','duration']]
df1.head()
# Out:
#           director                  title   duration
# 0  Kirsten Johnson   Dick Johnson Is Dead     90 min
# 1              NaN          Blood & Water  2 Seasons
# 2  Julien Leclercq              Ganglands   1 Season
# 3              NaN  Jailbirds New Orleans   1 Season
# 4              NaN           Kota Factory  2 Seasons

# %%
# First 100 rows & all columns
df_sub1=df.iloc[0:100,:]
df_sub1.head()
# Out:
#    id                  title         director  \
# 0  s1   Dick Johnson Is Dead  Kirsten Johnson
# 1  s2          Blood & Water              NaN
# 2  s3              Ganglands  Julien Leclercq
# 3  s4  Jailbirds New Orleans              NaN
# 4  s5           Kota Factory              NaN
#
#                                                 cast         origin  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#             time_info  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
#deleting last rows
df=df.drop(df.index[-1],axis=0) # Deletes last row
df.head()
# Out:
#    id                  title         director  \
# 0  s1   Dick Johnson Is Dead  Kirsten Johnson
# 1  s2          Blood & Water              NaN
# 2  s3              Ganglands  Julien Leclercq
# 3  s4  Jailbirds New Orleans              NaN
# 4  s5           Kota Factory              NaN
#
#                                                 cast         origin  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#             time_info  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# sorting by age say in decreasing order.
df=df.sort_values(by=['id'],ascending=False) # can specify multiple columns in a list as well.
df.head()
# Out:
#        id                                  title  \
# 998  s999                   Searching For Sheela
# 997  s998  Life in Color with David Attenborough
# 996  s997                             HOMUNCULUS
# 995  s996                              Vizontele
# 994  s995                  This Lady Called Life
#
#                              director  \
# 998                               NaN
# 997                               NaN
# 996                   Takashi Shimizu
# 995  Yılmaz Erdoğan, Ömer Faruk Sorak
# 994                      Kayode Kasum
#
#                                                   cast  \
# 998                                    Ma Anand Sheela
# 997                                 David Attenborough
# 996  Go Ayano, Ryo Narita, Yukino Kishii, Anna Ishi...
# 995  Yılmaz Erdoğan, Demet Akbağ, Altan Erkekli, Ce...
# 994  Bisola Aiyeola, Efa Iwara, Molawa Onajobi, Tin...
#
#                         origin       time_info  release_year rating  duration  \
# ...
